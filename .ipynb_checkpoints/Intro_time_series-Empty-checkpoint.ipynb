# %% [markdown]
# #### LIBRARY

# %% [markdown]
# #### Importer les données

# %%
# Out:
#        date           X
# 1  01/02/00  308.461888
# 2  01/03/00  248.070897
# 3  01/04/00  165.062298
# 4  01/05/00  134.983627
# 5  01/06/00  140.400959
# 6  01/07/00  154.224998
# 7  01/08/00  128.425658
# 8  01/09/00  130.484347
# 9  01/10/00  174.338614

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
# date       120 non-null object
# X          120 non-null float64
# notrend    120 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB

# %%
# Out:
#                 X       notrend
# count  120.000000  1.200000e+02
# mean   132.068183 -4.784321e-14
# std    139.984170  1.172076e+02
# min    -60.406517 -1.738165e+02
# 25%     19.918656 -7.964900e+01
# 50%     98.257705 -2.013082e+01
# 75%    218.673722  6.929945e+01
# max    541.374330  3.051108e+02

# %% [markdown]
# #### Représenter les données

# %% [markdown]
# #### Quelles suppositions peut-on faire sur ce signal?
# #### Tendance?
# #### Saisonnalité?

# %% [markdown]
# #### Déterminer la meilleure fenêtre pour une moyenne mobile et représenter le lissage.

# %% [markdown]
# #### Estimer la tendance en utilisant un modèle polynomial (polynome du temps)

# %% [markdown]
# #### A l'aide de la libraire adéquate, décomposer le signal en "trend", "saisonnality" et "noise"

# %% [markdown]
# #### Superposer les différents composants du signal

# %% [markdown]
# #### Etude du bruit

# %% [markdown]
# #### Définir ce qu'est l'autocorrelation

# %% [markdown]
# A time series is periodic if it repeats itself at equally spaced intervals, say, every 12 months.
# Autocorrelation Function (ACF): It is a measure of the correlation between the TS with a lagged
# version of itself. For instance at lag 5, ACF would compare series at time instant t1. . . t2 with
# series at instant t1-5. . . t2-5 (t1-5 and t2 being end points).

# %% [markdown]
# #### Prédiction
# #### Ajustez trois modèles AR, MA et ARMA avec des paramètres expliqués et afficher l'indicateur de performance associé.
# #### Quel(s) modèle(s) retenez-vous?

# %%
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      X   No. Observations:                  120
# Model:                     ARMA(4, 0)   Log Likelihood                -578.204
# Method:                       css-mle   S.D. of innovations             29.439
# Date:                Fri, 06 Sep 2019   AIC                           1168.408
# Time:                        09:21:14   BIC                           1185.133
# Sample:                             0   HQIC                          1175.200
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        253.8974    144.237      1.760      0.081     -28.802     536.597
# ar.L1.X        1.4962      0.092     16.224      0.000       1.315       1.677
# ar.L2.X       -0.8092      0.165     -4.902      0.000      -1.133      -0.486
# ...
